# %%
import csv
import os

# %%
arr = os.listdir()
print(arr)
# Out:
# ['yok_sehir_geo.csv', 'Untitled1.ipynb', '.DS_Store', 'yok_okul_goc_2018.csv', 'LICENSE', 'Week4_homework.ipynb', 'Untitled.ipynb', 'yok_okul_geo.csv', 'README.md', 'sehir_latlon.csv', 'yok_okul_link.csv', 'YOKATLAS_Goc.ipynb', 'YOK_sehirToGeoJSON.ipynb', '.ipynb_checkpoints', 'yok_okul_goc_2016.csv', 'yok_okul_goc.csv', 'yok_okul_goc_2017.csv', 'yok_mimarlik_data.csv', '.git', 'data']

# %%
filelist = ['yok_okul_goc_2018.csv', 'yok_okul_goc_2016.csv', 'yok_okul_goc.csv', 'yok_okul_goc_2017.csv']
okullist = []
sehirlist = []
totallist = []

# %%
with open('yok_okul_geo.csv', newline='') as f:
    reader = csv.reader(f)
    okullist = list(reader)
with open('yok_sehir_geo.csv', newline='') as f:
    reader = csv.reader(f)
    sehirlist = list(reader)
print(len(sehirlist), len(okullist))

for okul in okullist:
    for sehir in sehirlist:
        temp = [okul[0],okul[1],okul[2],sehir[0],sehir[1],sehir[2],0]
        totallist.append(temp)
# Out:
# 81 82

# %%
totallist
# Out:
# [['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Ankara',
#   '39.9207774',
#   '32.854067',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Adana',
#   '37.1438001',
#   '35.4984094',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bursa',
#   '40.182737',
#   '29.0678352',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Sivas',
#   '39.4191717',
#   '37.1012388',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Niğde',
#   '38.0664691',
#   '34.7051438',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Çorum',
#   '40.5698389',
#   '34.7269292',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Elazığ',
#   '38.5824771',
#   '39.396179',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kars',
#   '40.4558435',
#   '42.9979531',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Tokat',
#   '40.327747',
#   '36.5539494',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['KAYSERİ', '38.6582232', '35.5546374', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Aydın',
#   '37.8413007',
#   '27.8328374',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['KAYSERİ', '38.6582232', '35.5546374', 'Rize', '40.9347897', '40.827136', 0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Yozgat',
#   '39.7152422',
#   '35.170998',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Hatay',
#   '36.2025939',
#   '36.1603945',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'İzmir',
#   '38.4147331',
#   '27.1434119',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Siirt',
#   '37.8646916',
#   '42.0510294',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Düzce',
#   '40.8774545',
#   '31.2009618',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Iğdır',
#   '39.8945292',
#   '43.9427459',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['KAYSERİ', '38.6582232', '35.5546374', 'Muş', '38.9740786', '41.9590433', 0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Van',
#   '13.2904027',
#   '108.4265113',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Mardin',
#   '37.323983',
#   '40.7214269',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Sinop',
#   '41.6394277',
#   '34.8681231',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Muğla',
#   '37.1642053',
#   '28.2624288',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Ordu',
#   '40.8292569',
#   '37.4082764',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kilis',
#   '36.7797231',
#   '37.1416892',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Şırnak',
#   '37.519248',
#   '42.4605665',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bingöl',
#   '39.073803',
#   '40.7296181',
#   0],
#  ['KAYSERİ', '38.6582232', '35.5546374', 'Uşak', '38.609666', '29.3306506', 0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bolu',
#   '40.6212099',
#   '31.6460259',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Artvin',
#   '41.160506',
#   '41.8398627',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['KAYSERİ',
#   '38.6582232',
#   '35.5546374',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Ankara', '39.9207774', '32.854067', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Adana', '37.1438001', '35.4984094', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Bursa', '40.182737', '29.0678352', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Sivas', '39.4191717', '37.1012388', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Niğde', '38.0664691', '34.7051438', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Çorum', '40.5698389', '34.7269292', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Elazığ', '38.5824771', '39.396179', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Kars', '40.4558435', '42.9979531', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Konya', '37.8719963', '32.4844015', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Tokat', '40.327747', '36.5539494', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Aydın', '37.8413007', '27.8328374', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Rize', '40.9347897', '40.827136', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Yozgat', '39.7152422', '35.170998', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Hatay', '36.2025939', '36.1603945', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'İzmir', '38.4147331', '27.1434119', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Siirt', '37.8646916', '42.0510294', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Düzce', '40.8774545', '31.2009618', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Iğdır', '39.8945292', '43.9427459', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Muş', '38.9740786', '41.9590433', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Van', '13.2904027', '108.4265113', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Mardin', '37.323983', '40.7214269', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Sinop', '41.6394277', '34.8681231', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Muğla', '37.1642053', '28.2624288', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Ordu', '40.8292569', '37.4082764', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Kilis', '36.7797231', '37.1416892', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Şırnak', '37.519248', '42.4605665', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Bingöl', '39.073803', '40.7296181', 0],
#  ['ADANA', '37.1438001', '35.4984094', 'Uşak', '38.609666', '29.3306506', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Bolu', '40.6212099', '31.6460259', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['ADANA', '37.1438001', '35.4984094', 'Artvin', '41.160506', '41.8398627', 0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['ADANA',
#   '37.1438001',
#   '35.4984094',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Ankara',
#   '39.9207774',
#   '32.854067',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Adana',
#   '37.1438001',
#   '35.4984094',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Bursa', '40.182737', '29.0678352', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Sivas',
#   '39.4191717',
#   '37.1012388',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Niğde',
#   '38.0664691',
#   '34.7051438',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Çorum',
#   '40.5698389',
#   '34.7269292',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Elazığ',
#   '38.5824771',
#   '39.396179',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Kars', '40.4558435', '42.9979531', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Tokat', '40.327747', '36.5539494', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Aydın',
#   '37.8413007',
#   '27.8328374',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Rize', '40.9347897', '40.827136', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Yozgat',
#   '39.7152422',
#   '35.170998',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Hatay',
#   '36.2025939',
#   '36.1603945',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'İzmir',
#   '38.4147331',
#   '27.1434119',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Siirt',
#   '37.8646916',
#   '42.0510294',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Düzce',
#   '40.8774545',
#   '31.2009618',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Iğdır',
#   '39.8945292',
#   '43.9427459',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Muş', '38.9740786', '41.9590433', 0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Van', '13.2904027', '108.4265113', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Mardin',
#   '37.323983',
#   '40.7214269',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Sinop',
#   '41.6394277',
#   '34.8681231',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Muğla',
#   '37.1642053',
#   '28.2624288',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Ordu', '40.8292569', '37.4082764', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kilis',
#   '36.7797231',
#   '37.1416892',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Şırnak',
#   '37.519248',
#   '42.4605665',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Bingöl',
#   '39.073803',
#   '40.7296181',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Uşak', '38.609666', '29.3306506', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['ADIYAMAN', '37.78936', '38.3141101', 'Bolu', '40.6212099', '31.6460259', 0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Artvin',
#   '41.160506',
#   '41.8398627',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['ADIYAMAN',
#   '37.78936',
#   '38.3141101',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Ankara',
#   '39.9207774',
#   '32.854067',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Adana',
#   '37.1438001',
#   '35.4984094',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bursa',
#   '40.182737',
#   '29.0678352',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Sivas',
#   '39.4191717',
#   '37.1012388',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Niğde',
#   '38.0664691',
#   '34.7051438',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Çorum',
#   '40.5698389',
#   '34.7269292',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Elazığ',
#   '38.5824771',
#   '39.396179',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kars',
#   '40.4558435',
#   '42.9979531',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Tokat',
#   '40.327747',
#   '36.5539494',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Ağrı',
#   '39.52916',
#   '43.3835645',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Aydın',
#   '37.8413007',
#   '27.8328374',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Rize',
#   '40.9347897',
#   '40.827136',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Yozgat',
#   '39.7152422',
#   '35.170998',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Hatay',
#   '36.2025939',
#   '36.1603945',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'İzmir',
#   '38.4147331',
#   '27.1434119',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Siirt',
#   '37.8646916',
#   '42.0510294',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Düzce',
#   '40.8774545',
#   '31.2009618',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Iğdır',
#   '39.8945292',
#   '43.9427459',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Muş',
#   '38.9740786',
#   '41.9590433',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Van',
#   '13.2904027',
#   '108.4265113',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Mardin',
#   '37.323983',
#   '40.7214269',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Sinop',
#   '41.6394277',
#   '34.8681231',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Muğla',
#   '37.1642053',
#   '28.2624288',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Ordu',
#   '40.8292569',
#   '37.4082764',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kilis',
#   '36.7797231',
#   '37.1416892',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Şırnak',
#   '37.519248',
#   '42.4605665',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bingöl',
#   '39.073803',
#   '40.7296181',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Uşak',
#   '38.609666',
#   '29.3306506',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bolu',
#   '40.6212099',
#   '31.6460259',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Artvin',
#   '41.160506',
#   '41.8398627',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['AFYONKARAHİSAR',
#   '38.6852729',
#   '30.6427411',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Kayseri', '38.6582232', '35.5546374', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Ankara', '39.9207774', '32.854067', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Mersin', '36.8328277', '33.9685895', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Adana', '37.1438001', '35.4984094', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bursa', '40.182737', '29.0678352', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Malatya', '38.4820156', '38.1035355', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Sivas', '39.4191717', '37.1012388', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Erzurum', '39.7581897', '41.4032241', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'İstanbul', '41.0766019', '29.052495', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Niğde', '38.0664691', '34.7051438', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Batman', '37.7874104', '41.2573924', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Çorum', '40.5698389', '34.7269292', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Denizli', '37.8275892', '29.2389539', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Elazığ', '38.5824771', '39.396179', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Hakkari', '37.495358', '44.1054777', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Isparta', '37.9465412', '30.9602093', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Kars', '40.4558435', '42.9979531', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Konya', '37.8719963', '32.4844015', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Samsun', '41.2303557', '35.9683338', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Tokat', '40.327747', '36.5539494', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Trabzon', '40.8849863', '39.822206', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Aksaray', '38.4326291', '33.8976963', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Nevşehir', '38.7235072', '34.7194168', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Amasya', '40.6569451', '35.7727169', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Aydın', '37.8413007', '27.8328374', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bitlis', '38.4950867', '42.1678372', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Erzincan', '39.6073429', '39.2013209', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Manisa', '38.6155029', '27.4255716', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Rize', '40.9347897', '40.827136', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Sakarya', '40.7542228', '30.3834858', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Yozgat', '39.7152422', '35.170998', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Antalya', '36.9279654', '30.7276865', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Hatay', '36.2025939', '36.1603945', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Kocaeli', '40.8216536', '29.9507184', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Osmaniye', '37.2517882', '36.2993502', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Tekirdağ', '41.1185843', '27.4144196', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Çankırı', '40.6667691', '33.4526069', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'İzmir', '38.4147331', '27.1434119', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Siirt', '37.8646916', '42.0510294', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bilecik', '40.1435101', '29.9752911', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Düzce', '40.8774545', '31.2009618', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Iğdır', '39.8945292', '43.9427459', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Karaman', '37.1796848', '33.3383665', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Giresun', '40.6531617', '38.5172032', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Kütahya', '39.2522508', '29.4937732', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Muş', '38.9740786', '41.9590433', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Van', '13.2904027', '108.4265113', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Zonguldak', '41.250324', '31.8389738', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Karabük', '41.1110349', '32.6193901', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Mardin', '37.323983', '40.7214269', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Sinop', '41.6394277', '34.8681231', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Kırşehir', '39.1461142', '34.1605587', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Muğla', '37.1642053', '28.2624288', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['AĞRI', '39.52916', '43.3835645', 'Adıyaman', '37.78936', '38.3141101', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Ordu', '40.8292569', '37.4082764', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Kilis', '36.7797231', '37.1416892', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Ardahan', '41.0372501', '42.7462189', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Şırnak', '37.519248', '42.4605665', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bingöl', '39.073803', '40.7296181', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Uşak', '38.609666', '29.3306506', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Edirne', '41.6759327', '26.5587225', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Tunceli', '39.2197553', '39.4139674', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bolu', '40.6212099', '31.6460259', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Burdur', '37.5183407', '30.1691254', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Yalova', '40.6291846', '29.2500262', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Gümüşhane', '40.2061415', '39.309437', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Artvin', '41.160506', '41.8398627', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bayburt', '40.2023027', '40.2121599', 0],
#  ['AĞRI', '39.52916', '43.3835645', 'Bartın', '41.4947715', '32.4354255', 0],
#  ['AĞRI',
#   '39.52916',
#   '43.3835645',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Ankara',
#   '39.9207774',
#   '32.854067',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Adana',
#   '37.1438001',
#   '35.4984094',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bursa',
#   '40.182737',
#   '29.0678352',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Sivas',
#   '39.4191717',
#   '37.1012388',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Niğde',
#   '38.0664691',
#   '34.7051438',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Çorum',
#   '40.5698389',
#   '34.7269292',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Elazığ',
#   '38.5824771',
#   '39.396179',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kars',
#   '40.4558435',
#   '42.9979531',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Tokat',
#   '40.327747',
#   '36.5539494',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['ANTALYA', '36.9279654', '30.7276865', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Aydın',
#   '37.8413007',
#   '27.8328374',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['ANTALYA', '36.9279654', '30.7276865', 'Rize', '40.9347897', '40.827136', 0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Yozgat',
#   '39.7152422',
#   '35.170998',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Hatay',
#   '36.2025939',
#   '36.1603945',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'İzmir',
#   '38.4147331',
#   '27.1434119',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Siirt',
#   '37.8646916',
#   '42.0510294',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Düzce',
#   '40.8774545',
#   '31.2009618',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Iğdır',
#   '39.8945292',
#   '43.9427459',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['ANTALYA', '36.9279654', '30.7276865', 'Muş', '38.9740786', '41.9590433', 0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Van',
#   '13.2904027',
#   '108.4265113',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Mardin',
#   '37.323983',
#   '40.7214269',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Sinop',
#   '41.6394277',
#   '34.8681231',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Muğla',
#   '37.1642053',
#   '28.2624288',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Ordu',
#   '40.8292569',
#   '37.4082764',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kilis',
#   '36.7797231',
#   '37.1416892',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Şırnak',
#   '37.519248',
#   '42.4605665',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bingöl',
#   '39.073803',
#   '40.7296181',
#   0],
#  ['ANTALYA', '36.9279654', '30.7276865', 'Uşak', '38.609666', '29.3306506', 0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bolu',
#   '40.6212099',
#   '31.6460259',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Artvin',
#   '41.160506',
#   '41.8398627',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['ANTALYA',
#   '36.9279654',
#   '30.7276865',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Ankara',
#   '39.9207774',
#   '32.854067',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Adana',
#   '37.1438001',
#   '35.4984094',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Bursa',
#   '40.182737',
#   '29.0678352',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Sivas',
#   '39.4191717',
#   '37.1012388',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Niğde',
#   '38.0664691',
#   '34.7051438',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Çorum',
#   '40.5698389',
#   '34.7269292',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Elazığ',
#   '38.5824771',
#   '39.396179',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Kars',
#   '40.4558435',
#   '42.9979531',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Tokat',
#   '40.327747',
#   '36.5539494',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['AKSARAY', '38.4326291', '33.8976963', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Aydın',
#   '37.8413007',
#   '27.8328374',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['AKSARAY',
#   '38.4326291',
#   '33.8976963',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['AKSARAY',
# ...
#   '41.0372501',
#   '42.7462189',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kars',
#   '40.4558435',
#   '42.9979531',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Tokat',
#   '40.327747',
#   '36.5539494',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['ARDAHAN', '41.0372501', '42.7462189', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Aydın',
#   '37.8413007',
#   '27.8328374',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['ARDAHAN', '41.0372501', '42.7462189', 'Rize', '40.9347897', '40.827136', 0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Yozgat',
#   '39.7152422',
#   '35.170998',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Hatay',
#   '36.2025939',
#   '36.1603945',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'İzmir',
#   '38.4147331',
#   '27.1434119',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Siirt',
#   '37.8646916',
#   '42.0510294',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Düzce',
#   '40.8774545',
#   '31.2009618',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Iğdır',
#   '39.8945292',
#   '43.9427459',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['ARDAHAN', '41.0372501', '42.7462189', 'Muş', '38.9740786', '41.9590433', 0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Van',
#   '13.2904027',
#   '108.4265113',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Mardin',
#   '37.323983',
#   '40.7214269',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Sinop',
#   '41.6394277',
#   '34.8681231',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Muğla',
#   '37.1642053',
#   '28.2624288',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Ordu',
#   '40.8292569',
#   '37.4082764',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kilis',
#   '36.7797231',
#   '37.1416892',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Şırnak',
#   '37.519248',
#   '42.4605665',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Bingöl',
#   '39.073803',
#   '40.7296181',
#   0],
#  ['ARDAHAN', '41.0372501', '42.7462189', 'Uşak', '38.609666', '29.3306506', 0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Bolu',
#   '40.6212099',
#   '31.6460259',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Artvin',
#   '41.160506',
#   '41.8398627',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['ARDAHAN',
#   '41.0372501',
#   '42.7462189',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Ankara', '39.9207774', '32.854067', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Adana', '37.1438001', '35.4984094', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Bursa', '40.182737', '29.0678352', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Sivas', '39.4191717', '37.1012388', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Niğde', '38.0664691', '34.7051438', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Çorum', '40.5698389', '34.7269292', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Elazığ', '38.5824771', '39.396179', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Kars', '40.4558435', '42.9979531', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Konya', '37.8719963', '32.4844015', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Tokat', '40.327747', '36.5539494', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Amasya',
#   '40.6569451',
#   '35.7727169',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Aydın', '37.8413007', '27.8328374', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Bitlis',
#   '38.4950867',
#   '42.1678372',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Erzincan',
#   '39.6073429',
#   '39.2013209',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Eskişehir',
#   '39.6821156',
#   '31.0723476',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Manisa',
#   '38.6155029',
#   '27.4255716',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Rize', '40.9347897', '40.827136', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Sakarya',
#   '40.7542228',
#   '30.3834858',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Yozgat', '39.7152422', '35.170998', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Antalya',
#   '36.9279654',
#   '30.7276865',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Diyarbakır',
#   '38.0814716',
#   '40.4297767',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Hatay', '36.2025939', '36.1603945', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kocaeli',
#   '40.8216536',
#   '29.9507184',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Osmaniye',
#   '37.2517882',
#   '36.2993502',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Tekirdağ',
#   '41.1185843',
#   '27.4144196',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Çankırı',
#   '40.6667691',
#   '33.4526069',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'İzmir', '38.4147331', '27.1434119', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Siirt', '37.8646916', '42.0510294', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Bilecik',
#   '40.1435101',
#   '29.9752911',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Çanakkale',
#   '40.0549886',
#   '26.9278292',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Düzce', '40.8774545', '31.2009618', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Iğdır', '39.8945292', '43.9427459', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Karaman',
#   '37.1796848',
#   '33.3383665',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Giresun',
#   '40.6531617',
#   '38.5172032',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kütahya',
#   '39.2522508',
#   '29.4937732',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Muş', '38.9740786', '41.9590433', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Van', '13.2904027', '108.4265113', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Zonguldak',
#   '41.250324',
#   '31.8389738',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Karabük',
#   '41.1110349',
#   '32.6193901',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Mardin', '37.323983', '40.7214269', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Sinop', '41.6394277', '34.8681231', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kastamonu',
#   '41.3680217',
#   '33.7619177',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kırşehir',
#   '39.1461142',
#   '34.1605587',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Muğla', '37.1642053', '28.2624288', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Balıkesir',
#   '39.5400798',
#   '28.0228793',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Afyonkarahisar',
#   '38.6852729',
#   '30.6427411',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Adıyaman',
#   '37.78936',
#   '38.3141101',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Ordu', '40.8292569', '37.4082764', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Kilis', '36.7797231', '37.1416892', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Ardahan',
#   '41.0372501',
#   '42.7462189',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Şırnak', '37.519248', '42.4605665', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Bingöl', '39.073803', '40.7296181', 0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Uşak', '38.609666', '29.3306506', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Edirne',
#   '41.6759327',
#   '26.5587225',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Tunceli',
#   '39.2197553',
#   '39.4139674',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Bolu', '40.6212099', '31.6460259', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Burdur',
#   '37.5183407',
#   '30.1691254',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Yalova',
#   '40.6291846',
#   '29.2500262',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Gümüşhane',
#   '40.2061415',
#   '39.309437',
#   0],
#  ['ARTVİN', '41.160506', '41.8398627', 'Artvin', '41.160506', '41.8398627', 0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Bayburt',
#   '40.2023027',
#   '40.2121599',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Bartın',
#   '41.4947715',
#   '32.4354255',
#   0],
#  ['ARTVİN',
#   '41.160506',
#   '41.8398627',
#   'Kırklareli',
#   '41.7078046',
#   '27.6051334',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Kayseri',
#   '38.6582232',
#   '35.5546374',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Ankara',
#   '39.9207774',
#   '32.854067',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Mersin',
#   '36.8328277',
#   '33.9685895',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Adana',
#   '37.1438001',
#   '35.4984094',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Bursa',
#   '40.182737',
#   '29.0678352',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Malatya',
#   '38.4820156',
#   '38.1035355',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Sivas',
#   '39.4191717',
#   '37.1012388',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Erzurum',
#   '39.7581897',
#   '41.4032241',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'İstanbul',
#   '41.0766019',
#   '29.052495',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Kahramanmaraş',
#   '37.7830345',
#   '36.830655',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Niğde',
#   '38.0664691',
#   '34.7051438',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Batman',
#   '37.7874104',
#   '41.2573924',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Çorum',
#   '40.5698389',
#   '34.7269292',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Denizli',
#   '37.8275892',
#   '29.2389539',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Elazığ',
#   '38.5824771',
#   '39.396179',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Gaziantep',
#   '36.9666307',
#   '37.4074178',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Hakkari',
#   '37.495358',
#   '44.1054777',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Isparta',
#   '37.9465412',
#   '30.9602093',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Kars',
#   '40.4558435',
#   '42.9979531',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Konya',
#   '37.8719963',
#   '32.4844015',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Samsun',
#   '41.2303557',
#   '35.9683338',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Şanlıurfa',
#   '37.2595198',
#   '39.0408174',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Tokat',
#   '40.327747',
#   '36.5539494',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Trabzon',
#   '40.8849863',
#   '39.822206',
#   0],
#  ['ERZURUM', '39.7581897', '41.4032241', 'Ağrı', '39.52916', '43.3835645', 0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Aksaray',
#   '38.4326291',
#   '33.8976963',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Nevşehir',
#   '38.7235072',
#   '34.7194168',
#   0],
#  ['ERZURUM',
#   '39.7581897',
#   '41.4032241',
#   'Kırıkkale',
#   '39.8860105',
#   '33.8278992',
#   0],
#  ...]

# %%
for filename in filelist:
    with open(filename, newline='') as f:
        reader = csv.reader(f)
        data = list(reader)
    for each in data:
        if each[1] == totallist
    print(data[1])
# Out:
# ['2018', 'KAYSERİ', 'ABDULLAH GÜL ÜNİVERSİTESİ', 'Bilgisayar Mühendisliği(İngilizce)', 'lisans.php?y=106510077', 'Kayseri', '10', '% 19,2']
# ['2016', 'KAYSERİ', 'ABDULLAH GÜL ÜNİVERSİTESİ', 'Bilgisayar Mühendisliği(İngilizce)', 'lisans.php?y=106510077', 'Konya', '4', '% 25,0']
# ['2019', 'KAYSERİ', 'ABDULLAH GÜL ÜNİVERSİTESİ', 'Bilgisayar Mühendisliği(İngilizce)', 'lisans.php?y=106510077', 'Adana', '1', '%1,6']
# ['2017', 'KAYSERİ', 'ABDULLAH GÜL ÜNİVERSİTESİ', 'Bilgisayar Mühendisliği(İngilizce)', 'lisans.php?y=106510077', 'Kayseri', '4', '% 15,4']
